# %%
import chromadb
client = chromadb.Client()

# %%
collection = client.create_collection("news_articals")

# %%
collection.add(
    ids=["id1","id2","id3","id4"],
    documents=[
        "Apple is leading in a smart phone game with iphone sales up in 35%",
        "Tesla booked a minor profit of billion $in Q2",
        "Apples are high in fiber,vitamin C,and various antioxidants",
        "SpaceX got NASA contract worth 10 billion $",
    ]

)

# %%
data= collection.get(
    include=["documents","embeddings","metadatas"]
)

for i,emb in enumerate(data["embeddings"]):
    print(f"\nDocument{i+1}")
    print("Text:",data["documents"][i])
    print("Embedding length:",len(emb))
    print("First 10 values: ",emb[:10])
# Out:
# Document1
# Text: Apple is leading in a smart phone game with iphone sales up in 35%
# Embedding length: 384
# First 10 values:  [ 0.03435935  0.00997156  0.08675596 -0.12584969 -0.01862874  0.00508789
#   0.01277697  0.05696625  0.01802944  0.11429974]
#
# Document2
# Text: Tesla booked a minor profit of billion $in Q2
# Embedding length: 384
# First 10 values:  [ 0.03850481  0.09455863  0.0219505   0.06924413 -0.07325347 -0.02258548
#  -0.02874914  0.10128652  0.02959931  0.02702871]
#
# Document3
# Text: Apples are high in fiber,vitamin C,and various antioxidants
# Embedding length: 384
# First 10 values:  [ 0.04512429 -0.03145009  0.01100094  0.08058897  0.00119941  0.02187004
#  -0.00926966 -0.01325601  0.00425173  0.02350492]
#
# Document4
# Text: SpaceX got NASA contract worth 10 billion $
# Embedding length: 384
# First 10 values:  [-0.02309863  0.03526217  0.06101783 -0.02734388 -0.08042093 -0.02970157
#   0.07421495  0.05592685  0.02907891  0.07048371]

# %%
results = collection.query(
    query_texts=["This is a query related to Elon Musk"],
    n_results=2
)
print(results)
# Out:
# {'ids': [['id2', 'id4']], 'embeddings': None, 'documents': [['Tesla booked a minor profit of billion $in Q2', 'SpaceX got NASA contract worth 10 billion $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5093543529510498, 1.5598335266113281]]}
